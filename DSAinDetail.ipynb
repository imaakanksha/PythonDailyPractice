# %% [markdown]
# Simple Python Function to print.

# %%
def print_hi(name):
    print(f'Hi, {name}')
if __name__ == '__main__':
    print_hi('PyCharm')
# Out:
# Hi, PyCharm

# %% [markdown]
# Data Structures cam to be in order to handle large amount of data efficiently (for example with databases or internal indexing services)
#
# Modern Applications and softwares are manipulating large amount of data i.e. Facebook, Instagram etc.
#
# We can tune the running time complexity of given algorithms by using the appropriate data structure.
#
# There is always a trade-off between memory usage and running time of the underlying algorithm.
