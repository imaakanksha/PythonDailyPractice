# %% [markdown]
# The Calculator Project

# %%
print("Welcome to the Tip Calculator!")
Bill = float(input("What was the total Bill? $ "))
Tip = int(input("What percentage tip would you like to give? 10 12 15"))
People = int(input("How many people to split the bill?"))
tip_as_percent = Tip/100
total_tip_amount = Bill * tip_as_percent
total_bill = Bill + total_tip_amount
bill_per_person = total_bill/People
final_amount=round(bill_per_person, 2)
print(f"Each person should pay: ${final_amount}")
# Out:
# Welcome to the Tip Calculator!
# Each person should pay: $879.94

# %%
# Control Flow with If/else and Conditional Operators >,<,=>,=<
print("Welcome to the Rollercoaster!!!")
height = int(input("What is your height in CM?"))
if height >= 120:
    print("You can ride the RollerCoaster.")
else:
    print("Sorry, you have to grow taller before you can ride")
# Out:
# Welcome to the Rollercoaster!!!
# Sorry, you have to grow taller before you can ride

# %%
#Modulo Operator
#If the given Number is Even or Odd
number_to_check=int(input("What is the number you want to check?"))
if number_to_check % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Odd

# %%
#Nested If-Else Condition
print("Welcome to the Roller Coaster! ")
height = int(input("What is your height in cm?"))
if height >= 120:
    print("You can ride the Roller Coaster")
    age=int(input("What is you age?"))
    if age <= 18:
        print("Please pay $7.")
    else:
        print("Please pay $12.")
else:
    print("Sorry you have to grow taller before you can ride.")
# Out:
# Welcome to the Roller Coaster!
# You can ride the Roller Coaster
# Please pay $7.

# %%
#Elif Condition
print("Welcome to the Roller Coaster! ")
height = int(input("What is your height in cm?"))
bill =0
if height >= 120:
    print("You can ride the Roller Coaster")
    age=int(input("What is you age?"))
    if age <= 12:
        bill = 5
        print("Please pay $5.")
    elif age <= 18:
        bill = 7
        print("Please pay $7.")
    else:
        bill = 12
        print("Please pay $12.")
    
    wants_photo=input("Do you want to have a photo take? Type Y for Yes and N for No.")
    if wants_photo == "Y":
        #Add $3 to their bill.
        bill += 3
    print(f"Your final bill is {bill}")
else:
    print("Sorry you have to grow taller before you can ride.")
# Out:
# Welcome to the Roller Coaster!
# You can ride the Roller Coaster
# Please pay $12.
# Your final bill is 12

# %%
#BMI Calculator with Interpretations
print("BMI Calculator")
weight=int(input("What is the weight in Kg?"))
height=int(input("What is the height in CM?"))
bmi = weight/(height ** 2)
if bmi < 18.5:
    print("underweight")
elif bmi >= 18.5 and bmi <25:
    print("normal weight")
else:
    print("overweight")
# Out:
# BMI Calculator
# underweight

# %%
import random
import my_module
random_integer=random.randint(1,9)
print(random_integer)

print(my_module.my_favourite_number)
# Out:
# 3
# 3.1415

# %%
import random
import my_module
random_integer=random.randint(1,9)
print(random_integer)
random_number_0_to_1=random.random() *10
print(random_number_0_to_1)
random_float=random.uniform(1,10)
print(random_float)
print(my_module.my_favourite_number)
# Out:
# 6
# 0.7947878829287258
# 9.35883149716768
# 3.1415

# %%
import random
random_heads_or_tail=random.randint(0,1)
if random_heads_or_tail == 0:
    print("Heads")
else:
    print("Tails")
# Out:
# Tails

# %%
#List
states_of_India=["Bihar","Kashmir","Odissa","Jharkhand","Jammu","Chhatisgarh"]
print(states_of_India[-3])
print(states_of_India)
states_of_India.append(["Maharashtra","Tamil Nadu"])
print(states_of_India)
# Out:
# Jharkhand
# ['Bihar', 'Kashmir', 'Odissa', 'Jharkhand', 'Jammu', 'Chhatisgarh']
# ['Bihar', 'Kashmir', 'Odissa', 'Jharkhand', 'Jammu', 'Chhatisgarh', ['Maharashtra', 'Tamil Nadu']]

# %%
import random
friends=["Ram","Sam","Tom","Riya","Bob","Siya","Ben Tenison","Juli"]
print(random.choice(friends))
random_index=(random.randint(0,7))
print(friends[random_index])
# Out:
# Ben Tenison
# Juli

# %%
states_of_India=["Bihar","Kashmir","Odissa","Jharkhand","Jammu","Chhatisgarh"]
print(len(states_of_India))
print(states_of_India[-1])

fruits=["Strawberry","Banana","Orange","Guava","Cherry","Apple","Papaya"]
vegetables=["Spanish","Tomatoes","Potatoes","Cabbage","Raddish"]

dirty_dozen=[fruits,vegetables]
print(dirty_dozen)
# Out:
# 6
# Chhatisgarh
# [['Strawberry', 'Banana', 'Orange', 'Guava', 'Cherry', 'Apple', 'Papaya'], ['Spanish', 'Tomatoes', 'Potatoes', 'Cabbage', 'Raddish']]

# %%
#Rock-Paper-Sissor Game
import random
user_choice=int(input("What do you choose? Type 0 for Rock, 1 for Paper or 2 for Sissors.\n"))
computer_choice=random.randint(0,2)
print(f"Computer chose {computer_choice}")

if user_choice == 0 and computer_choice ==2:
    print("You win!")
elif computer_choice > user_choice:
    print("You Lose!")
else:
    print("You typed an invalid number, You ")
# Out:
# Computer chose 0
